# %% [markdown]
# # **Aliasing de Sinais Senoidais**
#
# A amostragem de sinais senoidais é um fenômeno em que ocorre a distorção do sinal devido a
# uma taxa insuficiente na amostragem de dados.
#
# Um exemplo abaixo: Qual a taxa de amostraem para um sinal senoidal de frequência de 20 Hz?
# Segundo Nyquist, a taxa de amostragem mínima para a recuperação deveria ser de 40 Hz.
#
# **CÓDIGO:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 20 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 20 * t)                  # Sinal de onda senoidal

# Amostrando o sinal a uma taxa de amostragem de 40 Hz
freq_40 = 40                                          # Frequência de amostragem
T_40 = 1 / freq_40                                    # Tempo de amostragem
t_sample_40 = np.arange(t0, tf, T_40)                 # Vetor de tempo de amostragem
s_sample_40 = np.sin(2 * np.pi * 20 * t_sample_40)    # Sinal de onda senoidal amostrado

# Amostrando o sinal a uma taxa de amostragem de 80 Hz
freq_80 = 80                                          # Frequência de amostragem
T_80 = 1 / freq_80                                    # Tempo de amostragem
t_sample_80 = np.arange(t0, tf, T_80)                 # Vetor de tempo de amostragem
s_sample_80 = np.sin(2 * np.pi * 20 * t_sample_80)    # Sinal de onda senoidal amostrado

# Amostrando o sinal a uma taxa de amostragem de 180 Hz
freq_180 = 180                                          # Frequência de amostragem
T_180 = 1 / freq_180                                    # Tempo de amostragem
t_sample_180 = np.arange(t0, tf, T_180)                 # Vetor de tempo de amostragem
s_sample_180 = np.sin(2 * np.pi * 20 * t_sample_180)    # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t_sample_40, s_sample_40)
plt.plot(t_sample_80, s_sample_80)
plt.plot(t_sample_180, s_sample_180)
plt.ylim(-1.1, 1.1)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.grid()
plt.legend(['40 Hz', '80 Hz', '180 Hz'])

plt.tight_layout()
plt.show()

# %% [markdown]
# Sempre existe alguma perda em um sinal amostrado. Contudo, o teorema de Nyquist-Shannon nos diz que o espectro de um sinal não será afetado pela sua discretização se esta ocorrer com uma frequência de amostragem duas vezes maior que a maior frequência do sinal. Amostragem que não respeita o limite de Nyquist pode distorcer o sinal
#
# ![](../Imagens/Unidade2/aliasingsenoidais.png)

# %% [markdown]
# Para calcular a frequência alias devido a amostragem que não seguiu o  critério de Nyquist é necessário usar a equação abaixo:
#
# $$f_a(N) = f_{in} - N \cdot f_s$$
#
# onde
# * $f_a$ é a frequência de aliasing.
# * $f_s$ é a taxa de amostragem.
# * $f_{in}$ é a frequência do sinal de entrada.

# %% [markdown]
# # **Gráfico das questão 12 ([Exercícios](/Unidade%202/exercicios_und_2.pdf))**
#
# ### **$f_0 = 8 Hz$**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 8 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 8 * t)                   # Sinal de onda senoidal

# Amostrando o sinal a uma taxa de amostragem de 40Hz
freq = 20                                       # Frequência de amostragem
T = 1 / freq                                    # Tempo de amostragem
t_sample = np.arange(t0, tf, T)                 # Vetor de tempo de amostragem
s_sample = np.sin(2 * np.pi * 8 * t_sample)     # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t, s, alpha=0.3)                          # Original
plt.plot(t_sample, s_sample, 'bo', label='sample') # Amostrado
plt.plot(t, s, 'r--', label='8 Hz')                # 8 Hz
plt.ylim(-1.1, 1.1)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **$f_0 = 12 Hz$**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 8 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 12 * t)                  # Sinal de onda senoidal
s_8 = np.sin(2 * np.pi * -8 * t)                 # Sinal de onda senoidal

# Amostrando o sinal a uma taxa de amostragem de 40Hz
freq = 20                                       # Frequência de amostragem
T = 1 / freq                                    # Tempo de amostragem
t_sample = np.arange(t0, tf, T)                 # Vetor de tempo de amostragem
s_sample = np.sin(2 * np.pi * 12 * t_sample)    # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t, s, alpha=0.3)                          # Original
plt.plot(t_sample, s_sample, 'bo', label='sample') # Amostrado
plt.plot(t, s_8, 'r--', label='-8 Hz')             # 8 Hz
plt.ylim(-1.1, 1.1)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **$f_0 = 20 Hz$**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 8 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 20 * t)                  # Sinal de onda senoidal
s_0 = np.sin(2 * np.pi * 0 * t)                 # Sinal de onda senoidal

# Amostrando o sinal a uma taxa de amostragem de 40Hz
freq = 20                                       # Frequência de amostragem
T = 1 / freq                                    # Tempo de amostragem
t_sample = np.arange(t0, tf, T)                 # Vetor de tempo de amostragem
s_sample = np.sin(2 * np.pi * 20 * t_sample)    # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t, s, alpha=0.3)                          # Original
plt.plot(t_sample, s_sample, 'bo',label=' Sample') # Amostrado
plt.plot(t, s_0, 'r--', label='0 Hz')              # 0 Hz
plt.ylim(-1.1, 1.1)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **$f_0 = 22 Hz$**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 8 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 22 * t)                  # Sinal de onda senoidal
s_2 = np.sin(2 * np.pi * 2 * t)

# Amostrando o sinal a uma taxa de amostragem de 40Hz
freq = 20                                       # Frequência de amostragem
T = 1 / freq                                    # Tempo de amostragem
t_sample = np.arange(t0, tf, T)                 # Vetor de tempo de amostragem
s_sample = np.sin(2 * np.pi * 22 * t_sample)    # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t, s, alpha=0.3)                          # Original 
plt.plot(t_sample, s_sample, 'bo', label='Sample') # Amostrado
plt.plot(t, s_2, 'r--', label='2 Hz')              # 2 Hz
plt.ylim(-1.1, 1.1)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **$f_0 = 32 Hz$**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gerando um sinal "contínuo" de onda senoidal - frequência de 8 Hz
t0 = 0                                          # Tempo inicial
tf = 0.5                                        # Tempo final
dt = 0.001                                      # Tempo de amostragem
t = np.arange(t0, tf, dt)                       # Vetor de tempo
s = np.sin(2 * np.pi * 32 * t)                  # Sinal de onda senoidal
s_8 = np.sin(2 * np.pi * -8 * t)                # Sinal de onda senoidal

# Amostrando o sinal a uma taxa de amostragem de 40Hz
freq = 20                                       # Frequência de amostragem
T = 1 / freq                                    # Tempo de amostragem
t_sample = np.arange(t0, tf, T)                 # Vetor de tempo de amostragem
s_sample = np.sin(2 * np.pi * 32 * t_sample)    # Sinal de onda senoidal amostrado

plt.figure(1, figsize=(10, 5))
# Plotando o sinal de onda senoidal
plt.subplot(2, 1, 1)
plt.plot(t, s)
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal')
plt.grid()

# Plotando o sinal de onda senoidal amostrado
plt.subplot(2, 1, 2)
plt.plot(t, s, alpha=0.3)                          # Original
plt.plot(t_sample, s_sample, 'bo', label='Sample') # Amostrado
plt.plot(t, s_8, 'r--', label='-8 Hz')              # 8 Hz
plt.ylim(-1.1, 1.1)          
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.title('Sinal de onda senoidal amostrado')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# # **REFERÊNCIAS BIBLIOGRÁFICAS**
#
# Disponível em: <https://edisciplinas.usp.br/pluginfile.php/1687929/mod_resource/content/0/AulaIntrodutoria.pdf>. ACesso em 20 de junho de 2022
